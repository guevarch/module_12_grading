# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## D Grade Errors
#
#  Missing code An update_many() query is performed to convert the latitude and longitude fields from strings to decimal numbers and RatingValue to integers (-4 )
#
#  Q1 - String Value - 8
#
#  Q2 - IndexError: no such item for Cursor instance -10
#
#  Q3 - Empty List, string wasn't converted to Int -8
#
#  Missing mongo import line (-5)

# %% [markdown]
# ## Notebook Set Up

# %% [markdown]
# Data Source: [UK Food Standards Agency](https://www.food.gov.uk/) (2022). UK food hygiene rating data API https://ratings.food.gov.uk/open-data/en-GB. Contains public sector information licensed under the [Open Government Licence v3.0](https://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/)<br />
# Accessed Sept 9, 2022 with the establishment settings as follows: longitude=51.5072, latitude=-0.1276, maxdistancelimit=4567, pagesize=10000, sortoptionkey=distance, pagenumber=(1,2,3).

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['restaurant', 'establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': '20'}
print("Number of documents in result: ", establishments.count_documents(query))
print("First result:")
results = establishments.find(query)
pprint(results[0])
# Out:
# Number of documents in result:  0
# First result:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\16474\Desktop\Coding\Bootcamp\module_12_grading\Grade D\Analysis.ipynb Cell 12 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/16474/Desktop/Coding/Bootcamp/module_12_grading/Grade%20D/Analysis.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> print("First result:")
#       <a href='vscode-notebook-cell:/c%3A/Users/16474/Desktop/Coding/Bootcamp/module_12_grading/Grade%20D/Analysis.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> results = establishments.find(query)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/16474/Desktop/Coding/Bootcamp/module_12_grading/Grade%20D/Analysis.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> pprint(results[0])
#
# File c:\Users\16474\anaconda3\lib\site-packages\pymongo\cursor.py:760, in Cursor.__getitem__(self, index)
#     758     for doc in clone:
#     759         return doc
# --> 760     raise IndexError("no such item for Cursor instance")
#     761 raise TypeError("index %r cannot be applied to Cursor instances" % index)
#
# IndexError: no such item for Cursor instance

# %%
# Convert the result to a Pandas DataFrame
hygiene_20 = establishments.find(query)
hygiene_20_df = pd.DataFrame(hygiene_20)
print("Documents in DataFrame: ", len(hygiene_20_df))
hygiene_20_df.head(10)
# Out:
# Documents in DataFrame:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  64dcc3eebb6944f9b89da857   110681                  0
# 1  64dcc3eebb6944f9b89dabd7   612039                  0
# 2  64dcc3efbb6944f9b89daee4   730933                  0
# 3  64dcc3efbb6944f9b89db0cf   172735                  0
# 4  64dcc3efbb6944f9b89db0f0   172953                  0
# 5  64dcc3efbb6944f9b89dba7d   512854                  0
# 6  64dcc3efbb6944f9b89dbca2  1537089                  0
# 7  64dcc3efbb6944f9b89dd1ca   155648                  0
# 8  64dcc3efbb6944f9b89dd60d  1012883                  0
# 9  64dcc3efbb6944f9b89dde1f   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': '0.27694', 'latitude': '50.769705'}
# 1  {'longitude': '1.278721', 'latitude': '51.8575...
# 2  {'longitude': '1.15927', 'latitude': '51.789429'}
# 3  {'longitude': '0.10202', 'latitude': '50.770885'}
# 4  {'longitude': '0.101446', 'latitude': '50.7707...
# 5  {'longitude': '0.736349', 'latitude': '51.5414...
# 6  {'longitude': '0.7121671', 'latitude': '51.535...
# 7  {'longitude': '0.602364', 'latitude': '51.5915...
# 8  {'longitude': '0.146449998021126', 'latitude':...
# 9  {'longitude': '0.462307', 'latitude': '51.57005'}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName': {'$regex':'London'}, 'RatingValue': {'$gte': 4}}
print("Number of documents in result: ", establishments.count_documents(query))
print("First result:")
results = establishments.find(query)
pprint(results[0])
# Out:
# Number of documents in result:  0
# First result:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\16474\Desktop\Coding\Bootcamp\module_12_grading\Grade D\Analysis.ipynb Cell 15 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/16474/Desktop/Coding/Bootcamp/module_12_grading/Grade%20D/Analysis.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> print("First result:")
#       <a href='vscode-notebook-cell:/c%3A/Users/16474/Desktop/Coding/Bootcamp/module_12_grading/Grade%20D/Analysis.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> results = establishments.find(query)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/16474/Desktop/Coding/Bootcamp/module_12_grading/Grade%20D/Analysis.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> pprint(results[0])
#
# File c:\Users\16474\anaconda3\lib\site-packages\pymongo\cursor.py:760, in Cursor.__getitem__(self, index)
#     758     for doc in clone:
#     759         return doc
# --> 760     raise IndexError("no such item for Cursor instance")
#     761 raise TypeError("index %r cannot be applied to Cursor instances" % index)
#
# IndexError: no such item for Cursor instance

# %%
# Convert the result to a Pandas DataFrame
london_4plus = establishments.find(query)
london_4plus_df = pd.DataFrame(london_4plus)
print("Documents in DataFrame: ", len(london_4plus_df))
london_4plus_df.head(10)

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Create the pipeline: match, then sort, then limit to 5
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {'geocode.latitude': {'$gte':latitude-degree_search, '$lte':latitude+degree_search}, 
         'geocode.longitude': {'$gte': longitude-degree_search, '$lte': longitude+degree_search},
         'RatingValue': 5}
sort = [('score.Hygiene', 1)]
limit = 5

# Print the results
pprint(list(establishments.find(query).sort(sort).limit(limit)))
# Out:
# []

# %%
# Convert result to Pandas DataFrame
near_penang_flavours = establishments.find(query).sort(sort).limit(limit)
near_penang_flavours_df = pd.DataFrame(near_penang_flavours)
near_penang_flavours_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by LocalAuthorityName
# 3. Sorts the matches from highest to lowest
# Mongosh version:
# db.establishments.aggregate( [ { $match: {'scores.Hygiene': 0}}, { $group: { _id: "$LocalAuthorityName", count: { $sum: 1 }}}])
pipeline = [
    {'$match': {'scores.Hygiene': 0}},
    {'$group': {'_id': "$LocalAuthorityName", 'count': { '$sum': 1 }}},
    {'$sort': { 'count': -1 }}
]

results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print("Number of documents in result: ", len(results))

# Print the first 10 results
pprint(results[0:10])
# Out:
# Number of documents in result:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert mongo result to Pandas DataFrame
result_df = pd.DataFrame(results)

print("Rows in DataFrame: ", len(result_df))
result_df.head(10)
